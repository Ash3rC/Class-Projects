# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash3rC/Class-Projects/blob/main/DSD_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Report: Analyzing VCT Madrid player and team performances

# %% [markdown]
# Source:
# Ryan Luong (2024) Valorant Champion Tour 2021-24 [Data Set]. Kaggle link:https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data
# This research was made with multiple data sets provided from the link above.

# %% [markdown]
# # --- Section 1: Introduction ---

# %% [markdown]
# This data set was retrieved from Kaggle in which I was provided with 21 different files. I chose 5 files to focus on which were files that generally consisted of all the statistics of player and team performances.
#
# I chose this data set as I enjoy watching VCT and wish to understand more into depth the performance of teams and players
# This data set provides statistics on quite literally everything that happened during the VCT Madrid scene
# In this analysis I will be analyzing the performance of players and teams based on all factors.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# These were all the different data sets provided to me. I used around 9 of them.

# %% [markdown]
# ![files.png](data:image/png;base64,...)

# %% [markdown]
# # --- Section 2: EDA ---

# %% [markdown]
# Column names to understand:
# ACS = Average Combat Score
# ADPR = Average Damage Per Round
#
# Based on the data:
#
#
# * ACS mean: 196.91
# * ACS median: 197.53
# * ACS STD: 32.03
# * ADPR mean: 130.35
# * ADPR median:129.57
# * ADPR STD: 19.74
# * Most picked agent: Viper 75%
# * Best performing map: Icebox
# * Worst performing map: Split
#
# Based on these stats we can confirm a few things. The highest picked agent being Viper means that the necesity of a smokes agent took priority out of every other agent type. We can also conclude that most players that participated in the tournament had an average adpr of 130 a round. This is 20 less than the average health of a player during full buy rounds which is interesting.

# %% [markdown]
# # --- Section 3: Visualizing ---

# %% [markdown]
# ![ADPR.png](data:image/png;base64,...)

# %% [markdown]
# *   The bar plot above shows the ADPR for all players. This helps to understand which players had the best performance as well as being able to quantify the ADPR of a team and correlate that to performance.

# %% [markdown]
# ![ADPR spread.png](data:image/png;base64,...)

# %% [markdown]
# * This histogram shows us the spread for the ADPR. As we can see the majority of players get an ADPR of 130. This is a guaranteed kill for eco rounds but isn't for full buy rounds. Interesting isn't it.

# %% [markdown]
# ![ACS bell.png](data:image/png;base64,...)

# %% [markdown]
# * After finding the average ADPR and the spread I wanted to see how ADPR affects ACS since ACS is basically the numeric rating of a players overall performance.
# * In order to do this I needed to find the mean and spread of all players ACS. So I created a histogram for all players ACS.

# %% [markdown]
# ![acs in corr adpr.png](data:image/png;base64,...)

# %% [markdown]
# * After finding the values for both ACS and ADPR, I needed a way to compare the two so I used a Hexbin to find ADPR's correlation to ACS.
# * This visual helps to correlate ADPR to ACS by using a third value that shows occurences and scaling.
# * A higher ADPR = higher ACS
# * This means that damage is a big part of ACS but isn't the only determining factor

# %% [markdown]
# ![map pick.png](data:image/png;base64,...)

# %% [markdown]
# * The next thing I wanted to do was find how the map effeceted a players ACS. But before I did that I wanted to plot a visual on the amount of times a map was played during the tournament.

# %% [markdown]
# ![All ACS.png](data:image/png;base64,...)

# %% [markdown]
# * By finding taking the data for the amount of times a certain map was played and the acs with that map I was able to plot a line graph like the one above. This graph helps to visualize what maps teams performed best on.

# %% [markdown]
# # Split ACS with outliers
#
#
# ![split outlier.png](data:image/png;base64,...)

# %% [markdown]
# # Icebox ACS with outliers
#
#
# ![icebox outlier.png](data:image/png;base64,...)

# %% [markdown]
# * When creating the line graph I wasn't particularly happy with the results I got as it didn't make sense to me why Split had such a bad ACS when it was the most played. Could it be because of outliers or could it just be because Split was played more?
# * By boxing these two box plots I would be able to identify outliers and the range plus the mean.
# * After looking at both plots I concluded that Split in general has a lower ACS than Icebox but also has a lot more games played. This means that the ACS for Split, even with outliers, is still worse than Icebox. This can mean that without the outliers Split's ACS would be horrendous.

# %% [markdown]
# ![map win rate.png](data:image/png;base64,...)

# %% [markdown]
# * Next I wanted to see which teams performed best on which maps. So I took the wins and losts of each team on each map and found the win lose rate for all of them. Based on the bar plot above, we can see that Sentinels went undefeated on the map Lotus. On the contrary FPX doesn't have a single bar on here. This means that they didn't win a single game.

# %% [markdown]
# ![side win lose.png](data:image/png;base64,...)

# %% [markdown]
# * I next wanted to understand which side won more based on the map. So I created a bar plot of all the win rates for Attacker side and Defender side. Thankfully this data was given by the data set so I didn't need to do any calculations.

# %% [markdown]
# ![agent pick.png](data:image/png;base64,...)

# %% [markdown]
# * The next factor I wanted to study was Agents. I wanted to see how much agents and team compositions affected ACS. But before I did that I needed to get a general idea of what the agent pick rate and win rate was.

# %% [markdown]
# ![split pick.png](data:image/png;base64,...)

# %% [markdown]
# * This bar plot represented the amount of times certain agents were picked on the map Split. With this bar plot I could compare it to another to see which agents were most influential.

# %% [markdown]
# ![lotus pick.png](data:image/png;base64,...)

# %% [markdown]
# * By comparing the two bar plots I was able to see a common trend between all maps. This was that smokes were of high priority to all teamp compositions.

# %% [markdown]
# ![team to win.png](data:image/png;base64,...)

# %% [markdown]
# * Lastly I took the amount of wins all agents had and ranked every agent out of 10. With this I was able to count the amount of times a team selected a certain agent and add up the over rating. After that I would divide the teams rating based on the total number of agent selections. This gave me a teams overall team composition. Which allowed me to create a hex plot with a third factor of overall team rank. The darker the color the better the team placed. As we can see, having the better team comp often leads to better placement. Any disturbance in that trend is do to exceptional individual performance.

# %% [markdown]
# # --- Section 4: Machine Learning ---

# %% [markdown]
# * My question that I want to answer with all this data is; "How much does a good team compostion, map choice, and overall player performance, play into a teams ability to win?
# * In order to answer this question I used multi linear regression to predict the win rates of all participated teams.

# %% [markdown]
# ![Screenshot 2024-07-26 201131.png](data:image/png;base64,...)

# %% [markdown]
# * The formula above is the way you would figure out the multi regression line by hand. Of course I didn't do this since computers are way better at doing calculations like this with no human error.
# * To get a better understanding as to what each variable means I'll explain it below.

# %% [markdown]
# ![Screenshot 2024-07-26 201327.png](data:image/png;base64,...)
# * This would be the y intercept value

# %% [markdown]
# ![Screenshot 2024-07-26 201542.png](data:image/png;base64,...)
# * This is the regression coefficient of the first independent variable

# %% [markdown]
# ![Screenshot 2024-07-26 201703.png](data:image/png;base64,...)
# * The regeression coefficient for the last independent variable

# %% [markdown]
# ![Screenshot 2024-07-26 201750.png](data:image/png;base64,...)
# * The model error

# %% [markdown]
# These were the results I got after using the model.
# The left side is the before and the right side is the after.
#
# ![Screenshot 2024-07-29 at 10.34.45 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![predict vis.png](data:image/png;base64,...)

# %% [markdown]
# ![predict plots.png](data:image/png;base64,...)

# %% [markdown]
# * These last two visuals are the predictions on the win rate of all the teams based on their team comp, the number of games played, team ACS, and overall win rate.
# * From the predictions we can see a multitude of changes to the standings of certain teams.
# * Originally all the teams were ranked based on their placement in the tournament. However, when you look at the prediction plot you can see team LOUD has surpassed the third placed team. We can also see that FPX has gone from a 0% win rate to a 13% win rate. It may not be the greatest but it certainly is an improvement.
# * Lastly, we can see that since Sentinels had the best rating on every single parameter, their win rate actually increased substantially.

# %% [markdown]
# # --- Section 5: Conclusion ---

# %% [markdown]
# From this study I was able to answer my initial question. The win rate in which a team has is heavily affected by all of the outlying factors I had mentioned earlier. A team must have a well rounded team composition in order to accel in a map. The type of map is also very important as to how a team deals with team composition adjustments. And lastly, the overall performance of a team and its players is crucial to the chance of a team winning a game. Through a multitude of different graphs and data frames, I was able to determine the strength of influence a certain aspect had on a teams chances of winning. Certain graphs gave me a general understanding of how players and teams performed based a certain something. While other graphs gave me detailed data on how much a certain something affected a teams performance.
#
# By using histograms I was able to determine the average damage per round for all players and the average combat score of all players. This also allowed for me to identify the correlation of damage to combat score. With this I was able confirm that the ability to get kills in a game can have a strong influence on the outcome of that game. In addition, I found that ceratain maps had better overall performance than others. This was important as team compostions would be built around certain maps and the teams ability to perform well in the tournament would be heavily affected by the map. In addition I found the agent select rates for certain maps. When doing this I found which agents had the highest win rate. This is important as agents with higher percentages meant that if teams didn't choose agents with higher percentages their chances of winning on a certain map signifigantly drops. With this in mind I found the ratings of all the teams team composition. With this new data I was able to create a hexbin graph that showed the win rate based on team composition. In this visual I was able to find that a better team composition lead to more wins.
#
# With all my factors taken into account I decided to make a multi linear regression model to predict the win rate of participated teams in the future. Of course when creating this model I understood that player performance is a factor that can drastically change throughout time. On top of that map choices most likely would not be the same. Disregarding those two minor issues I was able to develop a multi linear regression model to predict the win percents of teams based on, team composition, team ACS, and team win rate.
